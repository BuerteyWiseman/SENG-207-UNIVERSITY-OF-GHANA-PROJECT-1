# %% [markdown]
# ### Chacham Kofi Buertey
# ### 10961287
# ### Biomedical Engineering

# %% [markdown]
# ### Importing modules into jupyter for the project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Importing the data

# %%
dataset=pd.read_csv('data.csv')

# %%
dataset
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # Cleaning Dataset
# ###  We would clean the dataset by removing null values and duplicates

# %% [markdown]
# ### Finding out if there are null values in the entire dataset

# %% [markdown]
# #### To find out if there are null values in the entire dataset, we will find the general info of the data if there are discrepancies
# #### in the number of non null values, then we can conclude that there are null values that needs to be removed

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ### It can be seen from the info that there are discrepancies in the non-null counts, hence this confirms that there are null values in the dataset

# %% [markdown]
# ### Filling the null values using the means

# %%
meanfd=dataset['fixed acidity'].mean()

# %%
meanfd=dataset['fixed acidity'].mean()

# %%
meanfd
# Out:
# 8.319875000000001

# %%
meanvd=dataset['volatile acidity'].mean()

# %%
meancd=dataset['citric acid'].mean()
meanrs=dataset['residual sugar'].mean()
meanc=dataset['chlorides'].mean()
meanfsd=dataset['free sulfur dioxide'].mean()
meantsd=dataset['total sulfur dioxide'].mean()
meand=dataset['density'].mean()
meanpH=dataset['pH'].mean()
means=dataset['sulphates'].mean()
meana=dataset['alcohol'].mean()
meanq=dataset['quality'].mean()

# %%
dataset['quality']=dataset['quality'].fillna(meanq)

# %%
dataset['fixed acidity']=dataset['fixed acidity'].fillna(meanfd)
dataset['volatile acidity']=dataset['volatile acidity'].fillna(meanvd)
dataset['citric acid']=dataset['citric acid'].fillna(meancd)
dataset['residual sugar']=dataset['residual sugar'].fillna(meanrs)
dataset['chlorides']=dataset['chlorides'].fillna(meanc)
dataset['free sulfur dioxide']=dataset['free sulfur dioxide'].fillna(meanfsd)
dataset['total sulfur dioxide']=dataset['total sulfur dioxide'].fillna(meantsd)
dataset['density']=dataset['density'].fillna(meand)
dataset['pH']=dataset['pH'].fillna(meanpH)
dataset['sulphates']=dataset['sulphates'].fillna(means)
dataset['alcohol']=dataset['alcohol'].fillna(meana)

# %%
dataset
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# #### The method used was the fillna()approach using the mean. In this method, all the várious columns with various null values were analysed in detail and the mean values for the various values in each column was calculated. The mean for the various columns were then used to fill the respective null values for each of the columns'''

# %% [markdown]
# ## Finding out if there are duplicated values

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1601, dtype: bool

# %% [markdown]
# #### Though the values in the diagram states false throughout to indicate no dupliacted values, we must be reminded that the rows in the diagram above represent just a small fraction of the entire dataset and as such we cannot conclude  that there are no duplications in the dataset hence we use the dataset.drop_duplicates() to be satisfied and convinced

# %%
dataset=dataset.drop_duplicates()

# %%
dataset
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# ...

# %%
dataset.shape
# Out:
# (1601, 13)

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### This clearly indicates that there are no rows which are duplicated

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %% [markdown]
# ##### The data is now clean and ready for analysis

# %% [markdown]
# ## Showing statistical inferences

# %% [markdown]
# #### Here, we would find the mean, mode, median, standard deviation and variance for the entire dataset and also for the respective columns
# #### Note: I use the descriptive statistics approach and not the inferential statistics in this project. Hence, my inferences are based directly on my population and hence I do not generate any sample

# %% [markdown]
# ### Showing statistical inferences for my entire dataset

# %%
dataset.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# ##### Finding the mode of the entire dataset

# %%
dataset.mode()
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.2               0.6          0.0             2.0
# 1        2            NaN               NaN          NaN             NaN
# 2        3            NaN               NaN          NaN             NaN
# 3        4            NaN               NaN          NaN             NaN
# 4        5            NaN               NaN          NaN             NaN
# ...    ...            ...               ...          ...             ...
# 1596  1597            NaN               NaN          NaN             NaN
# 1597  1598            NaN               NaN          NaN             NaN
# 1598  1599            NaN               NaN          NaN             NaN
# 1599  1600            NaN               NaN          NaN             NaN
# 1600  1601            NaN               NaN          NaN             NaN
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density   pH  \
# ...

# %%
columns=['ID','fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide',
        'total sulfur dioxide','density','pH','sulphates','alcohol','quality']

# %% [markdown]
# ### Finding the statistical inferences of the individual columns in the dataset

# %%
for i in columns:
    print(dataset[i].describe())
    print('\n')
# Out:
# count    1601.000000
# mean      801.000000
# std       462.313206
# min         1.000000
# 25%       401.000000
# 50%       801.000000
# 75%      1201.000000
# max      1601.000000
# Name: ID, dtype: float64
#
#
# count    1601.000000
# mean        8.319875
# std         1.739495
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64
#
#
# count    1601.000000
# mean        0.527742
# std         0.178981
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64
#
#
# count    1601.000000
# mean        0.271175
# std         0.194684
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64
#
#
# count    1601.000000
# mean        2.538445
# std         1.409138
# min         0.900000
# ...

# %% [markdown]
# ### Finding the mode of the columns of the  individual columns in the entire dataset

# %%
dataset['fixed acidity'].mode()
# Out:
# 0    7.2
# Name: fixed acidity, dtype: float64

# %%
dataset['volatile acidity'].mode()
# Out:
# 0    0.6
# Name: volatile acidity, dtype: float64

# %%
dataset['citric acid'].mode()
# Out:
# 0    0.0
# Name: citric acid, dtype: float64

# %%
dataset['residual sugar'].mode()
# Out:
# 0    2.0
# Name: residual sugar, dtype: float64

# %%
dataset['chlorides'].mode()
# Out:
# 0    0.08
# Name: chlorides, dtype: float64

# %%
dataset['free sulfur dioxide'].mode()
# Out:
# 0    6.0
# Name: free sulfur dioxide, dtype: float64

# %%
dataset['total sulfur dioxide'].mode()
# Out:
# 0    28.0
# Name: total sulfur dioxide, dtype: float64

# %%
dataset['density'].mode()
# Out:
# 0    0.9972
# Name: density, dtype: float64

# %%
dataset['pH'].mode()
# Out:
# 0    3.3
# Name: pH, dtype: float64

# %%
dataset['sulphates'].mode()
# Out:
# 0    0.6
# Name: sulphates, dtype: float64

# %%
dataset['alcohol'].mode()
# Out:
# 0    9.5
# Name: alcohol, dtype: float64

# %%
dataset['quality'].mode()
# Out:
# 0    5.0
# Name: quality, dtype: float64

# %% [markdown]
# ### Finding the variance of the individual columns

# %%
dataset.var()
# Out:
# ID                      213733.500000
# fixed acidity                3.025842
# volatile acidity             0.032034
# citric acid                  0.037902
# residual sugar               1.985670
# chlorides                    0.002212
# free sulfur dioxide        109.311578
# total sulfur dioxide      1086.850537
# density                      0.000004
# pH                           0.023805
# sulphates                    0.028720
# alcohol                      1.135279
# quality                      0.651436
# dtype: float64

# %% [markdown]
# ### Correlation

# %%
datasetCorr=dataset.corr()

# %%
datasetCorr
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.267899         -0.009544    -0.153294
# fixed acidity        -0.267899       1.000000         -0.255557     0.670856
# volatile acidity     -0.009544      -0.255557          1.000000    -0.552909
# citric acid          -0.153294       0.670856         -0.552909     1.000000
# residual sugar       -0.031589       0.114595          0.001877     0.143517
# chlorides            -0.119131       0.093472          0.060748     0.203981
# free sulfur dioxide   0.091145      -0.152932         -0.010591    -0.061252
# total sulfur dioxide -0.113809      -0.113325          0.076247     0.036014
# density              -0.368725       0.667693          0.022753     0.364104
# pH                    0.135082      -0.682452          0.235182    -0.542637
# sulphates            -0.124243       0.182291         -0.261364     0.312839
# ...

# %% [markdown]
# ### Heat maps

# %% [markdown]
# ##### Here, I use the heat maps to easily conclude for the correlation diagram above as the numeric correlation diagram makes it
# ##### difficult for easy interpretation

# %%
sns.heatmap(datasetCorr,cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# #### HIDDEN INFERENCES FROM THE HEATMAP DIAGRAM
#
# #####  1. From the heatmap diagram above, the correlations between the various columns can be easily inferred. A deep green infers a strong positive correlation. As the deepness of the green color decreases, it infers a weak correlaton as it approaches negative.
# ##### 2. From the diagram, it is clearly seen that every column correlates at the maximum positive correlation of 1 against its own colum  and that is reasonable as the values are the same.
# #####  3. Also it can be clearly observed that the correlation between fixed acidity and pH approaches a minimum correlation as their correlation depicts a very very light color
# ##### 4. If we take a critical look at the heat map, it can be observed that  free sulfur dioxide and total sulfur dioxide have a pretty strong positive correlation as their correlation green color is quite deep depicting a strong correlation

# %% [markdown]
# ### Pie Chart
# ##### Here, I use pie chart to  find the percentage relations between the means of the various columns

# %%
MeanValues=[meanfd,meanvd,meancd,meanrs,meanc,meanfsd,meantsd,meand,meanpH,means,meana,meanq]
MeanLabels=['FixedAcidity','VolatileAcidity','CitricACid','ResidualSugar','Chlorides','FreeSulfurDioxide','TotalSulfurDioxide',
            'Density','pH','Sulphates','alcohol','quality']
plt.pie(MeanValues,startangle=90,autopct='%1.2f',labels= MeanLabels, explode=(0,2,0,4,1,0,1,2,3,0,0,0))

plt.show()

# %% [markdown]
# #### HIDDEN INFERENCE FROM THE PIE CHART
# ##### The exploded pie chart above explains the percentage of the means of the various columns in the entire dataset. It can be observed from the pie chart that in the comparison of the columns of the dataset, the mean of total Sulfur Dioxide occupies the largest portion of the chart with the chlorides occupying the least portion of the chart

# %%
hist_plot=dataset['total sulfur dioxide'].hist(bins=9)
hist_plot.set_xlabel('amount of the total sulfur dioxide')
hist_plot.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# #### HIDDEN INFERENCE FROM HISTOGRAM
# ##### This histogram is used analyse the frequency of the  amount of the total sulfur dioxide in the entire data set. It can be observed from the histogram that quantities within the range of 0-50 have the highest number of occurences in the dataset(frequency). Also values within the range of 200-300 hold the least number of frequency as values between 200-300 are significantly less in number

# %%
fig = plt.figure(figsize=(10,14), dpi=160)
explode = [0,0.1]
lb= ['Below', 'Above']
#4 rows 3 columns
# giving all
x= dataset['fixed acidity'] < dataset['fixed acidity'].mean()
#first row, first column
ax1 = plt.subplot2grid((4,3),(0,0))
plt.pie(x.value_counts(), colors=("g","r"),labels= lb, autopct = '%.2f%%', explode= explode)
plt.title('fixed_acidity')

y= dataset['volatile acidity'] < dataset['volatile acidity'].mean()
#first row sec column
ax2 = plt.subplot2grid((4,3),(0, 1))
plt.pie(y.value_counts(),colors=("g","r"),labels= lb, autopct = '%.2f%%', explode= explode)
plt.title('volatile_acidity')

z = dataset['citric acid'] < dataset['citric acid'].mean()
#first row thrird column
ax3 = plt.subplot2grid((4,3),(0, 2))
plt.pie(z.value_counts(),colors=("g","r"),labels= lb, autopct = '%.2f%%', explode= explode)
plt.title('citric_acid')
# Out:
# Text(0.5, 1.0, 'citric_acid')
